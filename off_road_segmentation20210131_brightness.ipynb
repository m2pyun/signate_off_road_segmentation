# %% [markdown]
# <a href="https://colab.research.google.com/github/m2pyun/signate_off_road_segmentation/blob/main/off_road_segmentation20210131_brightness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/m2pyun/signate_off_road_segmentation.git
# Out:
# Cloning into 'signate_off_road_segmentation'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 53 (delta 6), reused 45 (delta 5), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)#2. Get the file
train_A0 = drive.CreateFile({'id':'1amBnDtdmfwe6E4fMsD-9XuJPac9H2bwI'}) # replace the id with id of file you want to access
train_A1 = drive.CreateFile({'id':'1wl_vj4UlECr9NkdpzeP6PUj8T66OICyH'})
train_A2 = drive.CreateFile({'id':'1unrPOKP2GH1LVhlwDh1ypZ3_Do5UibvX'})
train_A3 = drive.CreateFile({'id':'1_mNWROSr7IZ24SeGMBT2ECKKfSd0ABXj'})
annotation_A = drive.CreateFile({'id':'1fFShS85-VxdkhJt58ngJxnicP6W8e3ew'})
train_A0.GetContentFile('train_A0.zip')
train_A1.GetContentFile('train_A1.zip')
train_A2.GetContentFile('train_A2.zip')
train_A3.GetContentFile('train_A3.zip')
annotation_A.GetContentFile('annotation_A.zip')


# !unzip train_A0.zip -d off_road
# !unzip train_A1.zip -d off_road
# !unzip train_A2.zip -d off_road
# !unzip train_A3.zip -d off_road
# !unzip annotation_A.zip -d off_road
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: off_road/train_images_A_1/train_image_A0831.png
#   inflating: off_road/train_images_A_1/train_image_A0832.png
#   inflating: off_road/train_images_A_1/train_image_A0833.png
#   inflating: off_road/train_images_A_1/train_image_A0834.png
#   inflating: off_road/train_images_A_1/train_image_A0835.png
#   inflating: off_road/train_images_A_1/train_image_A0836.png
#   inflating: off_road/train_images_A_1/train_image_A0837.png
#   inflating: off_road/train_images_A_1/train_image_A0838.png
#   inflating: off_road/train_images_A_1/train_image_A0839.png
#   inflating: off_road/train_images_A_1/train_image_A0840.png
#   inflating: off_road/train_images_A_1/train_image_A0841.png
#   inflating: off_road/train_images_A_1/train_image_A0842.png
#   inflating: off_road/train_images_A_1/train_image_A0843.png
#   inflating: off_road/train_images_A_1/train_image_A0844.png
#   inflating: off_road/train_images_A_1/train_image_A0845.png
#   inflating: off_road/train_images_A_1/train_image_A0846.png
#   inflating: off_road/train_images_A_1/train_image_A0847.png
#   inflating: off_road/train_images_A_1/train_image_A1411.png
#   inflating: off_road/train_images_A_1/train_image_A1412.png
#   inflating: off_road/train_images_A_1/train_image_A1413.png
#   inflating: off_road/train_images_A_1/train_image_A1414.png
#   inflating: off_road/train_images_A_1/train_image_A1415.png
#   inflating: off_road/train_images_A_1/train_image_A1416.png
#   inflating: off_road/train_images_A_1/train_image_A1417.png
#   inflating: off_road/train_images_A_1/train_image_A1418.png
#   inflating: off_road/train_images_A_1/train_image_A1419.png
#   inflating: off_road/train_images_A_1/train_image_A1420.png
#   inflating: off_road/train_images_A_1/train_image_A1421.png
#   inflating: off_road/train_images_A_1/train_image_A1422.png
#   inflating: off_road/train_images_A_1/train_image_A1423.png
#   inflating: off_road/train_images_A_1/train_image_A1424.png
#   inflating: off_road/train_images_A_1/train_image_A1425.png
#   inflating: off_road/train_images_A_1/train_image_A1426.png
#   inflating: off_road/train_images_A_1/train_image_A1037.png
#   inflating: off_road/train_images_A_1/train_image_A1038.png
#   inflating: off_road/train_images_A_1/train_image_A1039.png
#   inflating: off_road/train_images_A_1/train_image_A1040.png
#   inflating: off_road/train_images_A_1/train_image_A1041.png
#   inflating: off_road/train_images_A_1/train_image_A1042.png
#   inflating: off_road/train_images_A_1/train_image_A1043.png
#   inflating: off_road/train_images_A_1/train_image_A1044.png
#   inflating: off_road/train_images_A_1/train_image_A1045.png
#   inflating: off_road/train_images_A_1/train_image_A1046.png
#   inflating: off_road/train_images_A_1/train_image_A1047.png
#   inflating: off_road/train_images_A_1/train_image_A1048.png
#   inflating: off_road/train_images_A_1/train_image_A1049.png
#   inflating: off_road/train_images_A_1/train_image_A1050.png
#   inflating: off_road/train_images_A_1/train_image_A1051.png
#   inflating: off_road/train_images_A_1/train_image_A1052.png
#   inflating: off_road/train_images_A_1/train_image_A1053.png
#   inflating: off_road/train_images_A_1/train_image_A1054.png
#   inflating: off_road/train_images_A_1/train_image_A1055.png
#   inflating: off_road/train_images_A_1/train_image_A1056.png
#   inflating: off_road/train_images_A_1/train_image_A1057.png
#   inflating: off_road/train_images_A_1/train_image_A1058.png
#   inflating: off_road/train_images_A_1/train_image_A1059.png
#   inflating: off_road/train_images_A_1/train_image_A1060.png
#   inflating: off_road/train_images_A_1/train_image_A1061.png
#   inflating: off_road/train_images_A_1/train_image_A1062.png
#   inflating: off_road/train_images_A_1/train_image_A1063.png
#   inflating: off_road/train_images_A_1/train_image_A1064.png
#   inflating: off_road/train_images_A_1/train_image_A1065.png
#   inflating: off_road/train_images_A_1/train_image_A1066.png
#   inflating: off_road/train_images_A_1/train_image_A0988.png
#   inflating: off_road/train_images_A_1/train_image_A0989.png
#   inflating: off_road/train_images_A_1/train_image_A0990.png
#   inflating: off_road/train_images_A_1/train_image_A0991.png
#   inflating: off_road/train_images_A_1/train_image_A0992.png
#   inflating: off_road/train_images_A_1/train_image_A0993.png
#   inflating: off_road/train_images_A_1/train_image_A0994.png
#   inflating: off_road/train_images_A_1/train_image_A0995.png
#   inflating: off_road/train_images_A_1/train_image_A0996.png
#   inflating: off_road/train_images_A_1/train_image_A0997.png
#   inflating: off_road/train_images_A_1/train_image_A0998.png
#   inflating: off_road/train_images_A_1/train_image_A0999.png
#   inflating: off_road/train_images_A_1/train_image_A1000.png
#   inflating: off_road/train_images_A_1/train_image_A1001.png
#   inflating: off_road/train_images_A_1/train_image_A1002.png
#   inflating: off_road/train_images_A_1/train_image_A0960.png
#   inflating: off_road/train_images_A_1/train_image_A0961.png
#   inflating: off_road/train_images_A_1/train_image_A0962.png
#   inflating: off_road/train_images_A_1/train_image_A0963.png
#   inflating: off_road/train_images_A_1/train_image_A0964.png
#   inflating: off_road/train_images_A_1/train_image_A0965.png
#   inflating: off_road/train_images_A_1/train_image_A0966.png
#   inflating: off_road/train_images_A_1/train_image_A0967.png
#   inflating: off_road/train_images_A_1/train_image_A0968.png
#   inflating: off_road/train_images_A_1/train_image_A0969.png
#   inflating: off_road/train_images_A_1/train_image_A0970.png
#   inflating: off_road/train_images_A_1/train_image_A0971.png
#   inflating: off_road/train_images_A_1/train_image_A0972.png
#   inflating: off_road/train_images_A_1/train_image_A0973.png
#   inflating: off_road/train_images_A_1/train_image_A0974.png
#   inflating: off_road/train_images_A_1/train_image_A0975.png
#   inflating: off_road/train_images_A_1/train_image_A0976.png
#   inflating: off_road/train_images_A_1/train_image_A0977.png
#   inflating: off_road/train_images_A_1/train_image_A0978.png
#   inflating: off_road/train_images_A_1/train_image_A0979.png
#   inflating: off_road/train_images_A_1/train_image_A0980.png
#   inflating: off_road/train_images_A_1/train_image_A0981.png
#   inflating: off_road/train_images_A_1/train_image_A0982.png
#   inflating: off_road/train_images_A_1/train_image_A0983.png
#   inflating: off_road/train_images_A_1/train_image_A0984.png
#   inflating: off_road/train_images_A_1/train_image_A0985.png
#   inflating: off_road/train_images_A_1/train_image_A0986.png
#   inflating: off_road/train_images_A_1/train_image_A0881.png
#   inflating: off_road/train_images_A_1/train_image_A0882.png
#   inflating: off_road/train_images_A_1/train_image_A0883.png
#   inflating: off_road/train_images_A_1/train_image_A0884.png
#   inflating: off_road/train_images_A_1/train_image_A0885.png
#   inflating: off_road/train_images_A_1/train_image_A0886.png
#   inflating: off_road/train_images_A_1/train_image_A0887.png
#   inflating: off_road/train_images_A_1/train_image_A0888.png
#   inflating: off_road/train_images_A_1/train_image_A0889.png
#   inflating: off_road/train_images_A_1/train_image_A0890.png
#   inflating: off_road/train_images_A_1/train_image_A0891.png
#   inflating: off_road/train_images_A_1/train_image_A0892.png
#   inflating: off_road/train_images_A_1/train_image_A0893.png
#   inflating: off_road/train_images_A_1/train_image_A0894.png
#   inflating: off_road/train_images_A_1/train_image_A0895.png
#   inflating: off_road/train_images_A_1/train_image_A1343.png
#   inflating: off_road/train_images_A_1/train_image_A1344.png
#   inflating: off_road/train_images_A_1/train_image_A1345.png
#   inflating: off_road/train_images_A_1/train_image_A1346.png
#   inflating: off_road/train_images_A_1/train_image_A1347.png
#   inflating: off_road/train_images_A_1/train_image_A1348.png
#   inflating: off_road/train_images_A_1/train_image_A1349.png
#   inflating: off_road/train_images_A_1/train_image_A1350.png
#   inflating: off_road/train_images_A_1/train_image_A1351.png
#   inflating: off_road/train_images_A_1/train_image_A1352.png
#   inflating: off_road/train_images_A_1/train_image_A1353.png
#   inflating: off_road/train_images_A_1/train_image_A1354.png
#   inflating: off_road/train_images_A_1/train_image_A1355.png
#   inflating: off_road/train_images_A_1/train_image_A1356.png
#   inflating: off_road/train_images_A_1/train_image_A1357.png
#   inflating: off_road/train_images_A_1/train_image_A1359.png
#   inflating: off_road/train_images_A_1/train_image_A1360.png
#   inflating: off_road/train_images_A_1/train_image_A1361.png
#   inflating: off_road/train_images_A_1/train_image_A1362.png
#   inflating: off_road/train_images_A_1/train_image_A1363.png
#   inflating: off_road/train_images_A_1/train_image_A1364.png
#   inflating: off_road/train_images_A_1/train_image_A1365.png
#   inflating: off_road/train_images_A_1/train_image_A1366.png
#   inflating: off_road/train_images_A_1/train_image_A1367.png
#   inflating: off_road/train_images_A_1/train_image_A1368.png
#   inflating: off_road/train_images_A_1/train_image_A1369.png
#   inflating: off_road/train_images_A_1/train_image_A1370.png
#   inflating: off_road/train_images_A_1/train_image_A1371.png
#   inflating: off_road/train_images_A_1/train_image_A1372.png
#   inflating: off_road/train_images_A_1/train_image_A1373.png
#   inflating: off_road/train_images_A_1/train_image_A1374.png
#   inflating: off_road/train_images_A_1/train_image_A1375.png
#   inflating: off_road/train_images_A_1/train_image_A1376.png
#   inflating: off_road/train_images_A_1/train_image_A1468.png
#   inflating: off_road/train_images_A_1/train_image_A1469.png
#   inflating: off_road/train_images_A_1/train_image_A1470.png
#   inflating: off_road/train_images_A_1/train_image_A1471.png
#   inflating: off_road/train_images_A_1/train_image_A1472.png
#   inflating: off_road/train_images_A_1/train_image_A1473.png
#   inflating: off_road/train_images_A_1/train_image_A1474.png
#   inflating: off_road/train_images_A_1/train_image_A1475.png
#   inflating: off_road/train_images_A_1/train_image_A1476.png
#   inflating: off_road/train_images_A_1/train_image_A1477.png
#   inflating: off_road/train_images_A_1/train_image_A1478.png
#   inflating: off_road/train_images_A_1/train_image_A1479.png
#   inflating: off_road/train_images_A_1/train_image_A1480.png
#   inflating: off_road/train_images_A_1/train_image_A1481.png
#   inflating: off_road/train_images_A_1/train_image_A1482.png
#   inflating: off_road/train_images_A_1/train_image_A1261.png
#   inflating: off_road/train_images_A_1/train_image_A1262.png
#   inflating: off_road/train_images_A_1/train_image_A1263.png
#   inflating: off_road/train_images_A_1/train_image_A1264.png
#   inflating: off_road/train_images_A_1/train_image_A1265.png
#   inflating: off_road/train_images_A_1/train_image_A1266.png
#   inflating: off_road/train_images_A_1/train_image_A1267.png
#   inflating: off_road/train_images_A_1/train_image_A1268.png
#   inflating: off_road/train_images_A_1/train_image_A1269.png
#   inflating: off_road/train_images_A_1/train_image_A1270.png
#   inflating: off_road/train_images_A_1/train_image_A1271.png
#   inflating: off_road/train_images_A_1/train_image_A1272.png
#   inflating: off_road/train_images_A_1/train_image_A1273.png
#   inflating: off_road/train_images_A_1/train_image_A1274.png
#   inflating: off_road/train_images_A_1/train_image_A1275.png
#   inflating: off_road/train_images_A_1/train_image_A1276.png
#   inflating: off_road/train_images_A_1/train_image_A1277.png
#   inflating: off_road/train_images_A_1/train_image_A1278.png
#   inflating: off_road/train_images_A_1/train_image_A1279.png
#   inflating: off_road/train_images_A_1/train_image_A1280.png
#   inflating: off_road/train_images_A_1/train_image_A1281.png
#   inflating: off_road/train_images_A_1/train_image_A1282.png
#   inflating: off_road/train_images_A_1/train_image_A1283.png
#   inflating: off_road/train_images_A_1/train_image_A1284.png
#   inflating: off_road/train_images_A_1/train_image_A1285.png
#   inflating: off_road/train_images_A_1/train_image_A1286.png
#   inflating: off_road/train_images_A_1/train_image_A1287.png
#   inflating: off_road/train_images_A_1/train_image_A1288.png
#   inflating: off_road/train_images_A_1/train_image_A1158.png
#   inflating: off_road/train_images_A_1/train_image_A1159.png
#   inflating: off_road/train_images_A_1/train_image_A1160.png
#   inflating: off_road/train_images_A_1/train_image_A1161.png
#   inflating: off_road/train_images_A_1/train_image_A1162.png
#   inflating: off_road/train_images_A_1/train_image_A1163.png
#   inflating: off_road/train_images_A_1/train_image_A1164.png
#   inflating: off_road/train_images_A_1/train_image_A1165.png
#   inflating: off_road/train_images_A_1/train_image_A1166.png
#   inflating: off_road/train_images_A_1/train_image_A1167.png
#   inflating: off_road/train_images_A_1/train_image_A1168.png
#   inflating: off_road/train_images_A_1/train_image_A1169.png
#   inflating: off_road/train_images_A_1/train_image_A1170.png
#   inflating: off_road/train_images_A_1/train_image_A1171.png
#   inflating: off_road/train_images_A_1/train_image_A1172.png
#   inflating: off_road/train_images_A_1/train_image_A1173.png
#   inflating: off_road/train_images_A_1/train_image_A1174.png
#   inflating: off_road/train_images_A_1/train_image_A1175.png
#   inflating: off_road/train_images_A_1/train_image_A1176.png
#   inflating: off_road/train_images_A_1/train_image_A1177.png
#   inflating: off_road/train_images_A_1/train_image_A1178.png
#   inflating: off_road/train_images_A_1/train_image_A1179.png
#   inflating: off_road/train_images_A_1/train_image_A1180.png
#   inflating: off_road/train_images_A_1/train_image_A1181.png
#   inflating: off_road/train_images_A_1/train_image_A1182.png
#   inflating: off_road/train_images_A_1/train_image_A1183.png
#   inflating: off_road/train_images_A_1/train_image_A1184.png
#   inflating: off_road/train_images_A_1/train_image_A1185.png
#   inflating: off_road/train_images_A_1/train_image_A1204.png
#   inflating: off_road/train_images_A_1/train_image_A1205.png
#   inflating: off_road/train_images_A_1/train_image_A1206.png
#   inflating: off_road/train_images_A_1/train_image_A1207.png
#   inflating: off_road/train_images_A_1/train_image_A1208.png
#   inflating: off_road/train_images_A_1/train_image_A1209.png
#   inflating: off_road/train_images_A_1/train_image_A1210.png
#   inflating: off_road/train_images_A_1/train_image_A1211.png
#   inflating: off_road/train_images_A_1/train_image_A1212.png
#   inflating: off_road/train_images_A_1/train_image_A1213.png
#   inflating: off_road/train_images_A_1/train_image_A1214.png
#   inflating: off_road/train_images_A_1/train_image_A1215.png
#   inflating: off_road/train_images_A_1/train_image_A1216.png
#   inflating: off_road/train_images_A_1/train_image_A1217.png
#   inflating: off_road/train_images_A_1/train_image_A1218.png
#   inflating: off_road/train_images_A_1/train_image_A1219.png
#   inflating: off_road/train_images_A_1/train_image_A1220.png
#   inflating: off_road/train_images_A_1/train_image_A1221.png
#   inflating: off_road/train_images_A_1/train_image_A1222.png
#   inflating: off_road/train_images_A_1/train_image_A1223.png
#   inflating: off_road/train_images_A_1/train_image_A1224.png
#   inflating: off_road/train_images_A_1/train_image_A1225.png
#   inflating: off_road/train_images_A_1/train_image_A1226.png
#   inflating: off_road/train_images_A_1/train_image_A0897.png
#   inflating: off_road/train_images_A_1/train_image_A0898.png
#   inflating: off_road/train_images_A_1/train_image_A0899.png
#   inflating: off_road/train_images_A_1/train_image_A1442.png
#   inflating: off_road/train_images_A_1/train_image_A1443.png
#   inflating: off_road/train_images_A_1/train_image_A1444.png
#   inflating: off_road/train_images_A_1/train_image_A1445.png
#   inflating: off_road/train_images_A_1/train_image_A1446.png
#   inflating: off_road/train_images_A_1/train_image_A1447.png
#   inflating: off_road/train_images_A_1/train_image_A1448.png
#   inflating: off_road/train_images_A_1/train_image_A1449.png
#   inflating: off_road/train_images_A_1/train_image_A1157.png
#   inflating: off_road/train_images_A_1/train_image_A1186.png
#   inflating: off_road/train_images_A_1/train_image_A1203.png
#   inflating: off_road/train_images_A_1/train_image_A1227.png
#   inflating: off_road/train_images_A_1/train_image_A1243.png
#   inflating: off_road/train_images_A_1/train_image_A1260.png
#   inflating: off_road/train_images_A_1/train_image_A1289.png
#   inflating: off_road/train_images_A_1/train_image_A1305.png
#   inflating: off_road/train_images_A_1/train_image_A1325.png
#   inflating: off_road/train_images_A_1/train_image_A1342.png
#   inflating: off_road/train_images_A_1/train_image_A1358.png
#   inflating: off_road/train_images_A_1/train_image_A1377.png
#   inflating: off_road/train_images_A_1/train_image_A1393.png
#   inflating: off_road/train_images_A_1/train_image_A1410.png
#   inflating: off_road/train_images_A_1/train_image_A1427.png
#   inflating: off_road/train_images_A_1/train_image_A1450.png
#   inflating: off_road/train_images_A_1/train_image_A1467.png
#   inflating: off_road/train_images_A_1/train_image_A1483.png
#   inflating: off_road/train_images_A_1/train_image_A0782.png
#   inflating: off_road/train_images_A_1/train_image_A0783.png
#   inflating: off_road/train_images_A_1/train_image_A0784.png
#   inflating: off_road/train_images_A_1/train_image_A0785.png
#   inflating: off_road/train_images_A_1/train_image_A0786.png
#   inflating: off_road/train_images_A_1/train_image_A0787.png
#   inflating: off_road/train_images_A_1/train_image_A0788.png
#   inflating: off_road/train_images_A_1/train_image_A0789.png
#   inflating: off_road/train_images_A_1/train_image_A0790.png
#   inflating: off_road/train_images_A_1/train_image_A0791.png
#   inflating: off_road/train_images_A_1/train_image_A0792.png
#   inflating: off_road/train_images_A_1/train_image_A0793.png
#   inflating: off_road/train_images_A_1/train_image_A0794.png
#   inflating: off_road/train_images_A_1/train_image_A0795.png
#   inflating: off_road/train_images_A_1/train_image_A0796.png
#   inflating: off_road/train_images_A_1/train_image_A0797.png
#   inflating: off_road/train_images_A_1/train_image_A0798.png
#   inflating: off_road/train_images_A_1/train_image_A0799.png
#   inflating: off_road/train_images_A_1/train_image_A0800.png
#   inflating: off_road/train_images_A_1/train_image_A0801.png
#   inflating: off_road/train_images_A_1/train_image_A0802.png
#   inflating: off_road/train_images_A_1/train_image_A0803.png
#   inflating: off_road/train_images_A_1/train_image_A0804.png
#   inflating: off_road/train_images_A_1/train_image_A0805.png
#   inflating: off_road/train_images_A_1/train_image_A0806.png
#   inflating: off_road/train_images_A_1/train_image_A0807.png
#   inflating: off_road/train_images_A_1/train_image_A1121.png
#   inflating: off_road/train_images_A_1/train_image_A1122.png
#   inflating: off_road/train_images_A_1/train_image_A1123.png
#   inflating: off_road/train_images_A_1/train_image_A1124.png
#   inflating: off_road/train_images_A_1/train_image_A1125.png
#   inflating: off_road/train_images_A_1/train_image_A1126.png
#   inflating: off_road/train_images_A_1/train_image_A1127.png
#   inflating: off_road/train_images_A_1/train_image_A1128.png
#   inflating: off_road/train_images_A_1/train_image_A1129.png
#   inflating: off_road/train_images_A_1/train_image_A1130.png
#   inflating: off_road/train_images_A_1/train_image_A1131.png
#   inflating: off_road/train_images_A_1/train_image_A1132.png
#   inflating: off_road/train_images_A_1/train_image_A1133.png
#   inflating: off_road/train_images_A_1/train_image_A1134.png
#   inflating: off_road/train_images_A_1/train_image_A1135.png
#   inflating: off_road/train_images_A_1/train_image_A1136.png
#   inflating: off_road/train_images_A_1/train_image_A1137.png
#   inflating: off_road/train_images_A_1/train_image_A1138.png
#   inflating: off_road/train_images_A_1/train_image_A1139.png
#   inflating: off_road/train_images_A_1/train_image_A1140.png
#   inflating: off_road/train_images_A_1/train_image_A1484.png
#   inflating: off_road/train_images_A_1/train_image_A1485.png
#   inflating: off_road/train_images_A_1/train_image_A1486.png
#   inflating: off_road/train_images_A_1/train_image_A1487.png
#   inflating: off_road/train_images_A_1/train_image_A1488.png
#   inflating: off_road/train_images_A_1/train_image_A1489.png
#   inflating: off_road/train_images_A_1/train_image_A1490.png
#   inflating: off_road/train_images_A_1/train_image_A1491.png
#   inflating: off_road/train_images_A_1/train_image_A1492.png
#   inflating: off_road/train_images_A_1/train_image_A1493.png
#   inflating: off_road/train_images_A_1/train_image_A1494.png
#   inflating: off_road/train_images_A_1/train_image_A1495.png
#   inflating: off_road/train_images_A_1/train_image_A1496.png
#   inflating: off_road/train_images_A_1/train_image_A1497.png
#   inflating: off_road/train_images_A_1/train_image_A1498.png
#   inflating: off_road/train_images_A_1/train_image_A1499.png
#   inflating: off_road/train_images_A_1/train_image_A1306.png
#   inflating: off_road/train_images_A_1/train_image_A1307.png
#   inflating: off_road/train_images_A_1/train_image_A1308.png
#   inflating: off_road/train_images_A_1/train_image_A1309.png
#   inflating: off_road/train_images_A_1/train_image_A1310.png
#   inflating: off_road/train_images_A_1/train_image_A1311.png
#   inflating: off_road/train_images_A_1/train_image_A1312.png
#   inflating: off_road/train_images_A_1/train_image_A1313.png
#   inflating: off_road/train_images_A_1/train_image_A1314.png
#   inflating: off_road/train_images_A_1/train_image_A1315.png
#   inflating: off_road/train_images_A_1/train_image_A1316.png
#   inflating: off_road/train_images_A_1/train_image_A1317.png
#   inflating: off_road/train_images_A_1/train_image_A1318.png
#   inflating: off_road/train_images_A_1/train_image_A1319.png
#   inflating: off_road/train_images_A_1/train_image_A1320.png
#   inflating: off_road/train_images_A_1/train_image_A1321.png
#   inflating: off_road/train_images_A_1/train_image_A1322.png
#   inflating: off_road/train_images_A_1/train_image_A1323.png
#   inflating: off_road/train_images_A_1/train_image_A1324.png
#   inflating: off_road/train_images_A_1/train_image_A1394.png
#   inflating: off_road/train_images_A_1/train_image_A1395.png
#   inflating: off_road/train_images_A_1/train_image_A1396.png
#   inflating: off_road/train_images_A_1/train_image_A1397.png
#   inflating: off_road/train_images_A_1/train_image_A1398.png
#   inflating: off_road/train_images_A_1/train_image_A1399.png
#   inflating: off_road/train_images_A_1/train_image_A1400.png
#   inflating: off_road/train_images_A_1/train_image_A1401.png
#   inflating: off_road/train_images_A_1/train_image_A1402.png
#   inflating: off_road/train_images_A_1/train_image_A1403.png
#   inflating: off_road/train_images_A_1/train_image_A1404.png
#   inflating: off_road/train_images_A_1/train_image_A1405.png
#   inflating: off_road/train_images_A_1/train_image_A1406.png
#   inflating: off_road/train_images_A_1/train_image_A1407.png
#   inflating: off_road/train_images_A_1/train_image_A1408.png
#   inflating: off_road/train_images_A_1/train_image_A1409.png
#   inflating: off_road/train_images_A_1/train_image_A1020.png
#   inflating: off_road/train_images_A_1/train_image_A1021.png
#   inflating: off_road/train_images_A_1/train_image_A1022.png
#   inflating: off_road/train_images_A_1/train_image_A1023.png
#   inflating: off_road/train_images_A_1/train_image_A1024.png
#   inflating: off_road/train_images_A_1/train_image_A1025.png
#   inflating: off_road/train_images_A_1/train_image_A1026.png
#   inflating: off_road/train_images_A_1/train_image_A1027.png
#   inflating: off_road/train_images_A_1/train_image_A1028.png
#   inflating: off_road/train_images_A_1/train_image_A1029.png
#   inflating: off_road/train_images_A_1/train_image_A1030.png
#   inflating: off_road/train_images_A_1/train_image_A1031.png
#   inflating: off_road/train_images_A_1/train_image_A1032.png
#   inflating: off_road/train_images_A_1/train_image_A1033.png
#   inflating: off_road/train_images_A_1/train_image_A1034.png
#   inflating: off_road/train_images_A_1/train_image_A1035.png
#   inflating: off_road/train_images_A_1/train_image_A0943.png
#   inflating: off_road/train_images_A_1/train_image_A0944.png
#   inflating: off_road/train_images_A_1/train_image_A0945.png
#   inflating: off_road/train_images_A_1/train_image_A0946.png
#   inflating: off_road/train_images_A_1/train_image_A0947.png
#   inflating: off_road/train_images_A_1/train_image_A0948.png
#   inflating: off_road/train_images_A_1/train_image_A0949.png
#   inflating: off_road/train_images_A_1/train_image_A0950.png
#   inflating: off_road/train_images_A_1/train_image_A0951.png
#   inflating: off_road/train_images_A_1/train_image_A0952.png
#   inflating: off_road/train_images_A_1/train_image_A0953.png
#   inflating: off_road/train_images_A_1/train_image_A0954.png
#   inflating: off_road/train_images_A_1/train_image_A0955.png
#   inflating: off_road/train_images_A_1/train_image_A0956.png
#   inflating: off_road/train_images_A_1/train_image_A0957.png
#   inflating: off_road/train_images_A_1/train_image_A0958.png
#   inflating: off_road/train_images_A_1/train_image_A1084.png
#   inflating: off_road/train_images_A_1/train_image_A1085.png
#   inflating: off_road/train_images_A_1/train_image_A1086.png
#   inflating: off_road/train_images_A_1/train_image_A1087.png
#   inflating: off_road/train_images_A_1/train_image_A1088.png
#   inflating: off_road/train_images_A_1/train_image_A1089.png
#   inflating: off_road/train_images_A_1/train_image_A1090.png
#   inflating: off_road/train_images_A_1/train_image_A1091.png
#   inflating: off_road/train_images_A_2/train_image_A2203.png
#   inflating: off_road/train_images_A_2/train_image_A2204.png
#   inflating: off_road/train_images_A_2/train_image_A2205.png
#   inflating: off_road/train_images_A_2/train_image_A2206.png
#   inflating: off_road/train_images_A_2/train_image_A2207.png
#   inflating: off_road/train_images_A_2/train_image_A1990.png
#   inflating: off_road/train_images_A_2/train_image_A1991.png
#   inflating: off_road/train_images_A_2/train_image_A1992.png
#   inflating: off_road/train_images_A_2/train_image_A1993.png
#   inflating: off_road/train_images_A_2/train_image_A1994.png
#   inflating: off_road/train_images_A_2/train_image_A1995.png
#   inflating: off_road/train_images_A_2/train_image_A1996.png
#   inflating: off_road/train_images_A_2/train_image_A1997.png
#   inflating: off_road/train_images_A_2/train_image_A1998.png
#   inflating: off_road/train_images_A_2/train_image_A1999.png
#   inflating: off_road/train_images_A_2/train_image_A2000.png
#   inflating: off_road/train_images_A_2/train_image_A2001.png
#   inflating: off_road/train_images_A_2/train_image_A2002.png
#   inflating: off_road/train_images_A_2/train_image_A2003.png
#   inflating: off_road/train_images_A_2/train_image_A2004.png
#   inflating: off_road/train_images_A_2/train_image_A2005.png
#   inflating: off_road/train_images_A_2/train_image_A1794.png
#   inflating: off_road/train_images_A_2/train_image_A1795.png
#   inflating: off_road/train_images_A_2/train_image_A1796.png
#   inflating: off_road/train_images_A_2/train_image_A1797.png
#   inflating: off_road/train_images_A_2/train_image_A1798.png
#   inflating: off_road/train_images_A_2/train_image_A1799.png
#   inflating: off_road/train_images_A_2/train_image_A1800.png
#   inflating: off_road/train_images_A_2/train_image_A1801.png
#   inflating: off_road/train_images_A_2/train_image_A1802.png
#   inflating: off_road/train_images_A_2/train_image_A1803.png
#   inflating: off_road/train_images_A_2/train_image_A1804.png
#   inflating: off_road/train_images_A_2/train_image_A1805.png
#   inflating: off_road/train_images_A_2/train_image_A1806.png
#   inflating: off_road/train_images_A_2/train_image_A1807.png
#   inflating: off_road/train_images_A_2/train_image_A1808.png
#   inflating: off_road/train_images_A_2/train_image_A1809.png
#   inflating: off_road/train_images_A_2/train_image_A1810.png
#   inflating: off_road/train_images_A_2/train_image_A1811.png
#   inflating: off_road/train_images_A_2/train_image_A1812.png
#   inflating: off_road/train_images_A_2/train_image_A1813.png
#   inflating: off_road/train_images_A_2/train_image_A1814.png
#   inflating: off_road/train_images_A_2/train_image_A1815.png
#   inflating: off_road/train_images_A_2/train_image_A1816.png
#   inflating: off_road/train_images_A_2/train_image_A1817.png
#   inflating: off_road/train_images_A_2/train_image_A1818.png
#   inflating: off_road/train_images_A_2/train_image_A1819.png
#   inflating: off_road/train_images_A_2/train_image_A1820.png
#   inflating: off_road/train_images_A_2/train_image_A1838.png
#   inflating: off_road/train_images_A_2/train_image_A1839.png
#   inflating: off_road/train_images_A_2/train_image_A1840.png
#   inflating: off_road/train_images_A_2/train_image_A1841.png
#   inflating: off_road/train_images_A_2/train_image_A1842.png
#   inflating: off_road/train_images_A_2/train_image_A1843.png
#   inflating: off_road/train_images_A_2/train_image_A1844.png
#   inflating: off_road/train_annotations_A/train_annotation_A1011.png
#   inflating: off_road/train_annotations_A/train_annotation_A1012.png
#   inflating: off_road/train_annotations_A/train_annotation_A1013.png
#   inflating: off_road/train_annotations_A/train_annotation_A1014.png
#   inflating: off_road/train_annotations_A/train_annotation_A1015.png
#   inflating: off_road/train_annotations_A/train_annotation_A1016.png
#   inflating: off_road/train_annotations_A/train_annotation_A1017.png
#   inflating: off_road/train_annotations_A/train_annotation_A1850.png
#   inflating: off_road/train_annotations_A/train_annotation_A1851.png
#   inflating: off_road/train_annotations_A/train_annotation_A1852.png
#   inflating: off_road/train_annotations_A/train_annotation_A1853.png
#   inflating: off_road/train_annotations_A/train_annotation_A1854.png
#   inflating: off_road/train_annotations_A/train_annotation_A1855.png
#   inflating: off_road/train_annotations_A/train_annotation_A1856.png
#   inflating: off_road/train_annotations_A/train_annotation_A1857.png
#   inflating: off_road/train_annotations_A/train_annotation_A1858.png
#   inflating: off_road/train_annotations_A/train_annotation_A1859.png
#   inflating: off_road/train_annotations_A/train_annotation_A1860.png
#   inflating: off_road/train_annotations_A/train_annotation_A1861.png
#   inflating: off_road/train_annotations_A/train_annotation_A1862.png
#   inflating: off_road/train_annotations_A/train_annotation_A1863.png
#   inflating: off_road/train_annotations_A/train_annotation_A1864.png
#   inflating: off_road/train_annotations_A/train_annotation_A1865.png
#   inflating: off_road/train_annotations_A/train_annotation_A1866.png
#   inflating: off_road/train_annotations_A/train_annotation_A1192.png
#   inflating: off_road/train_annotations_A/train_annotation_A1193.png
#   inflating: off_road/train_annotations_A/train_annotation_A1194.png
#   inflating: off_road/train_annotations_A/train_annotation_A1195.png
#   inflating: off_road/train_annotations_A/train_annotation_A1196.png
#   inflating: off_road/train_annotations_A/train_annotation_A1197.png
#   inflating: off_road/train_annotations_A/train_annotation_A1198.png
#   inflating: off_road/train_annotations_A/train_annotation_A1199.png
#   inflating: off_road/train_annotations_A/train_annotation_A1200.png
#   inflating: off_road/train_annotations_A/train_annotation_A1201.png
#   inflating: off_road/train_annotations_A/train_annotation_A1202.png
#   inflating: off_road/train_annotations_A/train_annotation_A1203.png
#   inflating: off_road/train_annotations_A/train_annotation_A1204.png
#   inflating: off_road/train_annotations_A/train_annotation_A1205.png
#   inflating: off_road/train_annotations_A/train_annotation_A1206.png

# %%
precision = drive.CreateFile({'id':'1MN8kwpPPN-BUsJKnrkiuofv8UdejY3ki'})
precision.GetContentFile('precision.zip')
# !unzip precision.zip -d off_road

# %%
tutorial_model = drive.CreateFile({'id':'1jtE9PTopW5sSZA6rO20_5u8fz2zQLWs0'})
tutorial_model.GetContentFile('tutorial_model.pkl')

# %%
import os
from glob import glob
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']
from PIL import Image
import torch
import torch.utils.data as data
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms

print(torch.__version__)
print(torch.cuda.is_available())

# 評価対象カテゴリ
eval_names = ('road','dirt road', 'other obstacle')
eval_colors = ((128, 64, 128), (255, 128, 128), (0, 0, 70))
# Out:
# 1.7.0+cu101
# True

# %%
train_images_path_list = sorted(glob('off_road/train_images_A*/*.png'))
train_annotations_path_list = sorted(glob('off_road/train_annotations_A/*.png'))
precision_test_images_path_list = sorted(glob('off_road/precision_test_images/*.png'))

print('================')
print('学習用画像: ')
print(len(train_images_path_list))
print(train_images_path_list[:5])
print('================')
print('学習用アノテーション: ')
print(len(train_annotations_path_list))
print(train_annotations_path_list[:5])
print('================')
print('精度評価用画像: ')
print(len(precision_test_images_path_list))
print(precision_test_images_path_list[:5])
# Out:
# ================
# 学習用画像:
# 3007
# ['off_road/train_images_A_0/train_image_A0000.png', 'off_road/train_images_A_0/train_image_A0001.png', 'off_road/train_images_A_0/train_image_A0002.png', 'off_road/train_images_A_0/train_image_A0003.png', 'off_road/train_images_A_0/train_image_A0004.png']
# ================
# 学習用アノテーション:
# 3007
# ['off_road/train_annotations_A/train_annotation_A0000.png', 'off_road/train_annotations_A/train_annotation_A0001.png', 'off_road/train_annotations_A/train_annotation_A0002.png', 'off_road/train_annotations_A/train_annotation_A0003.png', 'off_road/train_annotations_A/train_annotation_A0004.png']
# ================
# 精度評価用画像:
# 640
# ['off_road/precision_test_images/precision_test_image_0000.png', 'off_road/precision_test_images/precision_test_image_0001.png', 'off_road/precision_test_images/precision_test_image_0002.png', 'off_road/precision_test_images/precision_test_image_0003.png', 'off_road/precision_test_images/precision_test_image_0004.png']

# %%
# 画像の読み込み

image_0000 = Image.open('off_road/train_images_A/train_image_A0000.png')
annotation_0000 = Image.open('off_road/train_annotations_A/train_annotation_A0000.png')

# 可視化
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

axes[0].imshow(image_0000)
axes[0].set_title('train_image_A0000.png')

axes[1].imshow(annotation_0000)
axes[1].set_title('train_annotation_A0000.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-0218494dfb7a> in <module>()
#       1 # 画像の読み込み
#       2
# ----> 3 image_0000 = Image.open('off_road/train_images_A*/train_image_A0000.png')
#       4 annotation_0000 = Image.open('off_road/train_annotations_A/train_annotation_A0000.png')
#       5
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'off_road/train_images_A*/train_image_A0000.png'

# %%
count = {
    'road': 0,
    'dirt road': 0,
    'other obstacle':0
}

for train_annotation_path in train_annotations_path_list:
    image = np.array(Image.open(train_annotation_path))
    
    for eval_name, eval_color in zip(eval_names, eval_colors):
        mask = (image==eval_color).sum(axis=2)==3
        if np.any(mask):
            count[eval_name] += 1
            
plt.bar(count.keys(), count.values())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-19e72ab6b40b> in <module>()
#       9
#      10     for eval_name, eval_color in zip(eval_names, eval_colors):
# ---> 11         mask = (image==eval_color).sum(axis=2)==3
#      12         if np.any(mask):
#      13             count[eval_name] += 1
#
# KeyboardInterrupt:

# %%
class OffRoadTransform():
    def __init__(self, image_size, mean, std):
        self.image_size = image_size
        self.mean = mean
        self.std = std
        
    def __call__(self, image, annotation):
        
        # リサイズ
        image = image.resize((self.image_size[1], self.image_size[0]))        
        annotation = annotation.resize((self.image_size[1], self.image_size[0]))


        # テンソル化&標準化

        image = transforms.functional.to_tensor(image)

        #明るさ
        brightness = 0.8
        brightness_factor = np.random.uniform(max(0, 1 - brightness), 1 + brightness)
        image = transforms.functional.adjust_brightness(image, brightness_factor)
        
        image = transforms.functional.normalize(image, self.mean, self.std)
        
        # アノテーション画像の色(RGB)情報を以下のように対応するようマッピングし、2次元の配列に変換する
        """
        road(128, 64, 128) -> 1
        dirt road(255, 128, 128) -> 2
        other obstacle(0, 0, 70) -> 3
        上記以外 -> 0
        """
        annotation = np.array(annotation)
        converted_annotation = np.zeros(annotation.shape[:-1])
        for i, eval_color in enumerate(eval_colors):
            mask = (annotation==eval_color).sum(axis=2)==3
            converted_annotation[mask] = i+1
        annotation = torch.from_numpy(converted_annotation)
        
        return image, annotation

# %%
class OffRoadDataset(data.Dataset):
    def __init__(self, image_list, annotation_list, transform):
        self.image_list = image_list
        self.annotation_list = annotation_list
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, index):

        image_filepath = self.image_list[index]
        annotation_filepath = self.annotation_list[index]
        
        image = Image.open(image_filepath)
        annotation = Image.open(annotation_filepath)

        image, annotation = self.transform(image, annotation)
        
        return image, annotation

# %%
train_dataset = OffRoadDataset(train_images_path_list, train_annotations_path_list,
                              transform=OffRoadTransform(image_size=(270, 480), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)))

print(train_dataset.__getitem__(0)[0].shape)
print(train_dataset.__getitem__(0)[1].shape)
# Out:
# torch.Size([3, 270, 480])
# torch.Size([270, 480])

# %%
batch_size = 4
train_dataloader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
net = torchvision.models.segmentation.deeplabv3_resnet101(pretrained=True)

# %%
net.classifier[-1] = nn.Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))

# %%
# 学習済みモデルの読み込み
net = pd.read_pickle("tutorial_model.pkl")

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# %%
def train(net, train_dataloader, criterion, optimizer, n_epoch):
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(device)
    
    net.to(device)
    net.train()

    for epoch in range(1, n_epoch+1):
        epoch_train_loss = 0.0
        optimizer.zero_grad()
        
        for images, annotations in train_dataloader:
            images = images.to(device)
            annotations = annotations.to(device)
            optimizer.step()
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = net(images)['out']
                loss = criterion(outputs, annotations.long())
                loss.backward()
                
        print(f'Epoch {epoch} finished')

    pd.to_pickle(net, "tutorial_model_0131.pkl".format(n_epoch))

# %%
train(net, train_dataloader, criterion, optimizer, n_epoch=10)
# Out:
# cuda:0
# Epoch 1 finished
# Epoch 2 finished
# Epoch 3 finished
# Epoch 4 finished
# Epoch 5 finished
# Epoch 6 finished
# Epoch 7 finished
# Epoch 8 finished
# Epoch 9 finished
# Epoch 10 finished

# %%
# 学習済みモデルの読み込み
net = pd.read_pickle("tutorial_model.pkl")

# %%
# デバイスの設定
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
net.eval()

# 前処理クラスのインスタンス化
test_transform = OffRoadTransform(image_size=(270, 480), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

# 画像データの読み込み
test_image_0000 = Image.open('off_road/precision_test_images/precision_test_image_0000.png')
dummy_annotation = Image.open('off_road/train_annotations_A/train_annotation_A0000.png')

image_transformed, _ = test_transform(test_image_0000, dummy_annotation)
image_transformed = image_transformed.unsqueeze(0)
image_transformed = image_transformed.to(device)

# 推論の実行
prediction = net(image_transformed)['out']
prediction = prediction[0].to('cpu').detach().numpy()
prediction = np.argmax(prediction, axis=0).astype('uint8')
prediction = np.array(Image.fromarray(prediction).resize([1920, 1080]))

# 推論結果をRGB画像に変換
RGB = np.zeros([1080, 1920, 3], dtype='uint8')
for i, color in enumerate(eval_colors):
    mask = prediction==i+1
    RGB[mask] = color
RGB_prediction = np.array(Image.fromarray(RGB).resize([1920, 1080]))

# 可視化
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

axes[0].imshow(test_image_0000)
axes[0].set_title('元画像')

axes[1].imshow(RGB_prediction)
axes[1].set_title('予測結果')
# Out:
# Text(0.5, 1.0, '予測結果')
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20803 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30011 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20803 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30011 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32080 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32080 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26524 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def pred2dict(fname, prediction):
    categories = [('road',[128, 64, 128]),('dirt road',[255, 128, 128]),('other obstacle',[0, 0, 70])]
    pred_dict = {}
    pred_dict[fname]={}
    
    for i,category in enumerate(categories):

        category_segments_pred = {}
        x_pred, y_pred = np.where(prediction==(i+1))
        category_pix_pred = {}

        for i,j in zip(x_pred,y_pred):
            if i not in category_pix_pred:
                category_pix_pred[i]=[]
            category_pix_pred[i].append(j)   

        for l in category_pix_pred:
            segments = []
            num_segments = 0
            for i,v in enumerate(sorted(category_pix_pred[l])):
                if i==0:
                    start=v
                    end=v
                else:
                    if v==end+1:
                        end = v
                    else:
                        segments.append([int(start),int(end)])
                        start = v
                        end = v
                        num_segments+=1
            segments.append([int(start),int(end)])
            category_segments_pred[int(l)]=segments
        if len(category_pix_pred):
            pred_dict[fname][category[0]]=category_segments_pred
        
    return pred_dict

# %%
def make_submission_file():
    
    categories = [('road',[128, 64, 128]),('dirt road',[255, 128, 128]),('other obstacle',[0, 0, 70])]
    predictions = {}
    
    # デバイスの設定
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    
    net.eval()
    
    # 前処理クラスのインスタンス化
    test_transform = OffRoadTransform(image_size=(270, 480), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
    
    # 画像一枚ずつに対して処理を実行するループ
    for test_image_path in precision_test_images_path_list:
        
        fname = os.path.basename(test_image_path)
        test_image = Image.open(test_image_path)
        dummy_annotation = Image.open('off_road/train_annotations_A/train_annotation_A0000.png')
        test_image, _ = test_transform(test_image, dummy_annotation)
        
        # ミニバッチ化
        test_image = test_image.unsqueeze(0).to(device)
        
        # 推論の実行
        prediction = net(test_image)['out']
        prediction = prediction[0].to('cpu').detach().numpy()
        prediction = np.argmax(prediction, axis=0).astype('uint8')
        prediction = np.array(Image.fromarray(prediction).resize([1920, 1080]))
        
        # 関数pred2dictを用いて予測画像を辞書形式に変換
        pred_dict = pred2dict(fname, prediction)
        predictions.update(pred_dict)

    with open(f'tutorial_submission1.json', 'w') as f:
        json.dump(predictions, f)

# %%
make_submission_file()
